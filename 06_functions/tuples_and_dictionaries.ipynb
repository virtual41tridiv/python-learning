# %% [markdown]
# ## Tuples

# %%
def find_pe_and_pb (price,eps,book_value):
    pe = price/eps
    pb = price/book_value
    return pe,pb

# %%
pe_ratio, pb_ratio = find_pe_and_pb(150,5,25)

# %%
pe_ratio
# Out:
# 30.0

# %%
pb_ratio
# Out:
# 6.0
