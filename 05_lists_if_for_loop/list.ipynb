# %% [markdown]
# ## LISTS

# %%
items = ["bread","pasta","fruits","vegetables"]
items
# Out:
# ['bread', 'pasta', 'fruits', 'vegetables']

# %%
items[3]
# Out:
# 'vegetables'

# %%
items[-1]
# Out:
# 'vegetables'

# %%
items[-3]
# Out:
# 'pasta'

# %%
items[0:2]
# Out:
# ['bread', 'pasta']

# %%
items.append("butter")

# %%
items
# Out:
# ['bread', 'pasta', 'fruits', 'vegetables', 'butter']

# %%
items.remove("butter")

# %%
items.insert(1,"butter")
items
# Out:
# ['bread', 'butter', 'pasta', 'fruits', 'vegetables']

# %%
items[1] = 'cheese'
items
# Out:
# ['bread', 'cheese', 'pasta', 'fruits', 'vegetables']

# %%
items[3:] = ['almonds']
items
# Out:
# ['bread', 'cheese', 'pasta', 'almonds']

# %%
'rice' in items
# Out:
# False

# %%
'bread' in items
# Out:
# True

# %%
expenses = [2200,350, 2600, 130, 2190]
expenses.sort()
expenses
# Out:
# [130, 350, 2190, 2200, 2600]

# %%
expenses.clear()
expenses
# Out:
# []
