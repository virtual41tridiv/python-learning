# %% [markdown]
# ## Numbers

# %%
base =10
height = 12

area = (base * height)/2
area
# Out:
# 60.0

# %%
type(area)
# Out:
# float

# %%
x=10
y=3

# %%
x+y
# Out:
# 13

# %%
x-y
# Out:
# 7

# %%
x*y
# Out:
# 30

# %%
x/y
# Out:
# 3.3333333333333335

# %%
x//y
# Out:
# 3

# %%
x%y
# Out:
# 1

# %%
x,y
# Out:
# (10, 3)

# %%
x**y
# Out:
# 1000

# %%
10+2*3+6**2
# Out:
# 52

# %%
foo=2.3e4
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
bar=2.3e-4
bar
# Out:
# 0.00023

# %%
food = 500.50
rent = 8000
utilities = 1250.66

# %%
total_expenses = food + rent + utilities
total_expenses
# Out:
# 9751.16

# %%
round(total_expenses)
# Out:
# 9751

# %%
round(total_expenses, 1)
# Out:
# 9751.2

# %%
income = 25000
expenses= 12890
savings = income - expenses
savings
# Out:
# 12110

# %%
food = '120.34'
rent = '300.54'

total = float(food) + float(rent)
total
# Out:
# 420.88

# %%
food = '120.34'
rent = '300.54'

total = food + rent
total
# Out:
# '120.34300.54'

# %%
food
# Out:
# '120.34'

# %%
type(food)
# Out:
# str

# %%
float(food)
# Out:
# 120.34

# %%
type(float(food))
# Out:
# float

# %%
import math

x=16
math.sqrt(x)
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.2)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(math.pi, '.2f')
# Out:
# '3.14'

# %%
format(5,'b')
# Out:
# '101'

# %%
format(4,'b')
# Out:
# '100'

# %%
format(math.pi, '.4f')
# Out:
# '3.1416'
